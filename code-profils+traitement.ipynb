# %%
from selenium import webdriver
import pandas as pd
import os 

from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# Configurer le pilote
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Charger la page de connexion
driver.get("https://www.linkedin.com/login")

# Identifiants de l'utilisateur
user_name = 'dohachamss283@gmail.com'
password = 'Chamssdoha2003328'
WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID, "username"))).send_keys(user_name)
WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID, "password"))).send_keys(password)

# Bouton de connexion
elements = driver.find_elements('xpath', '//*[@id="organic-div"]/form/div[3]/button')
elements[0].click()

# %%
L=["https://www.linkedin.com/in/abdelhalim-asfiri/","https://www.linkedin.com/in/oumaymatouji/","https://www.linkedin.com/in/imane-chaoui-4b012368/"," https://www.linkedin.com/in/abdessamad-azrour/", "https://www.linkedin.com/in/ziyadharroud/",
"https://www.linkedin.com/in/imane-benchqroun-969736194/","https://www.linkedin.com/in/samaha-eddalili-376321159/","https://www.linkedin.com/in/mouad-assaital-b560981a3/","https://www.linkedin.com/in/mariam-janati-idrissi-b8b274199/",
"https://www.linkedin.com/in/anas-saaoudi-b49676181/","https://www.linkedin.com/in/elhami7/","https://www.linkedin.com/in/reda-menaoui/","https://www.linkedin.com/in/monia-el-adib-253a45178/","https://www.linkedin.com/in/badr-eddine-aboulkacem/"
,"https://www.linkedin.com/in/fatima-al-hammouti-05bbb71a1/","https://www.linkedin.com/in/abdelhak-elbiari-a46b80195/",
"https://www.linkedin.com/in/yassine-toumi-373bb51a2/","https://www.linkedin.com/in/rebbaj-chamsseddine-36b4a81b1/",
"https://www.linkedin.com/in/mounia-katih/","https://www.linkedin.com/in/mehdi-belchiti/"," https://www.linkedin.com/in/chouiekhadil/","https://www.linkedin.com/in/yassine-bourichi-aa22a060/","https://www.linkedin.com/in/bassma-el-ghazaz-8339751aa/"
,"https://www.linkedin.com/in/asmaeamnas/",
"https://www.linkedin.com/in/moncefbender/",
"https://www.linkedin.com/in/kaoutarbouchdak/",
"https://www.linkedin.com/in/fatima-ezzahra-jarmouni/",
"https://www.linkedin.com/in/ismail-ougamane/",
"https://www.linkedin.com/in/ismaïl-lahbabi-a2000763/", "https://www.linkedin.com/in/marouan-el-n-80066b1a6/",
"https://www.linkedin.com/in/hanae-mourinou-08b260118/",
"https://www.linkedin.com/in/omar-elkassi-0639b77/",
"https://www.linkedin.com/in/mohamed-el-mamoun/",
"https://www.linkedin.com/in/yousra-el-messoussi/",
"https://www.linkedin.com/in/hajarrezzouqi/",
"https://www.linkedin.com/in/abdennour-el-malki/",
"https://www.linkedin.com/in/wafae-bourjilat/",
"https://www.linkedin.com/in/riad-zineb-93a563171/",
"https://www.linkedin.com/in/yousrabouzambou/",
"https://www.linkedin.com/in/anas-gourzi/",
"https://www.linkedin.com/in/zineb-zrhari-261205197/",
"https://www.linkedin.com/in/saiddaif/",
"https://www.linkedin.com/in/miloud-link",
"https://www.linkedin.com/in/abbaouibi/",
   "https://www.linkedin.com/in/oumaima-khattabi/", "https://www.linkedin.com/in/oussama-jaafar/", "https://www.linkedin.com/in/amal-el-briki-19487a15b/" ,
   "https://www.linkedin.com/in/houssam-addad/"  ,
   "https://www.linkedin.com/in/mounirbelghiti/",
   "https://www.linkedin.com/in/zineb-zrhari-261205197/"  ]

# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import WebDriverException

# Initialize lists to store extracted data
names = []
companies = []
locs = []
certifs = []
final_formations = []

for link in L:
    try:
        # Load the profile page
        driver.get(link)
        time.sleep(8)
        src = driver.page_source
        soup = BeautifulSoup(src, 'lxml')

        # Retrieve the name
        name_element = soup.find('h1', {'class': 'text-heading-xlarge inline t-24 v-align-middle break-words'})
        if name_element is not None:
            name = name_element.get_text().strip()
        else:
            name = ""
            print("Name element not found on the page.")

        # Retrieve the location
        loc_element = soup.find('span', {'class': 'text-body-small inline t-black--light break-words'})
        if loc_element is not None:
            loc = loc_element.get_text().strip()
        else:
            loc = ""
            print("Location element not found on the page.")

        # Retrieve the company
        company_element = soup.find('div', {'class': 'inline-show-more-text'})
        if company_element is not None:
            company = company_element.get_text().strip()
        else:
            company = ""
            print("Company element not found on the page.")

        try:
            full_link_certifications = link + "details/certifications/"
            driver.get(full_link_certifications)
            time.sleep(8)
            src_certifications = driver.page_source
            soup_certifications = BeautifulSoup(src_certifications, 'lxml')

            # Retrieve the certifications
            certifs_divs = soup_certifications.find_all('div', class_='display-flex flex-row justify-space-between')
            certifications = []
            for div in certifs_divs:
                competence_span = div.find('span', class_='mr1 hoverable-link-text t-bold')
                if competence_span:
                    competence = competence_span.find('span', attrs={"aria-hidden": "true"})
                    if competence:
                        certifications.append(competence.text.strip())

            # Convert the list of certifications into a comma-separated string
            certifications_str = ", ".join(certifications)

        except WebDriverException as e:
            certifications_str = ""
            print(f"Error accessing certifications: {e}")

        # Construct the full education link
        full_link_education = link + "details/education/"

        # Load the education page
        driver.get(full_link_education)
        time.sleep(8)
        src_education = driver.page_source
        soup_education = BeautifulSoup(src_education, 'html.parser')

        # Retrieve the extracted formations
        extracted_formations = []
        elements_education = soup_education.find_all('span', class_='mr1 hoverable-link-text t-bold')
        for element in elements_education:
            formation = element.text.strip()
            extracted_formations.append(formation)

        # Check the first position of the extracted formations list
        if extracted_formations and extracted_formations[0] == "Ecole Nationale Supérieure d'Informatique et d'Analyse des Systèmes - ENSIASEcole Nationale Supérieure d'Informatique et d'Analyse des Systèmes - ENSIAS":
            result = "No"
        else:
            result = "DD"

        # Append the extracted data to the lists
        names.append(name)
        companies.append(company)
        locs.append(loc)
        certifs.append(certifications_str)
        final_formations.append(result)

    except WebDriverException as e:
        print(f"Error accessing profile: {e}")
# Out:
# Company element not found on the page.
# Name element not found on the page.
# Location element not found on the page.
# Company element not found on the page.

# %%
# Create a DataFrame from the extracted data
data = {
    "Name": names,
    "Company": companies,
    "Location": locs,
    "Certifications": certifs,
    "Formations": final_formations
}
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#                       Name                            Company  \
# 0   Abdelhalim Asfiri Eng.                                IBM
# 1            Oumayma Touji                    Orange Business
# 2             Imane CHAOUI                             OCP SA
# 3        Abdessamad Azrour                           INTELCIA
# 4            Ziyad HARROUD                Business & Decision
# ..                     ...                                ...
# 95          Oussama JAAFAR                       Confidential
# 96           Amal EL BRIKI                           INTELCIA
# 97   Houssam Zakaria Addad                               Bell
# 98         Mounir BELGHITI  Ministère d'agriculture Marocaine
# 99            Zineb ZRHARI                             Umanis
#
#                                           Location  \
# 0                 Rabat, Rabat-Salé-Kénitra, Maroc
# 1                 Rabat, Rabat-Salé-Kénitra, Maroc
# 2                                            Maroc
# ...

# %%
# Save the DataFrame to a CSV file
df.to_csv("linkedin_data.csv", index=False)

# %%
df.to_excel("linkedin_data.xlsx", index=False)

# %%
import os

current_directory = os.getcwd()
print("Current Directory:", current_directory)
# Out:
# Current Directory: C:\Users\ACH

# %%
# Lecture du fichier Excel
df = pd.read_excel(r"C:\Users\ACH\result-loc-trait.xlsx")

# Traitement de la colonne "Location"
df.loc[df["Location"].str.contains("Casablanca", case=False), "Location"] = "Casablanca "
df.loc[df["Location"].str.contains("Rabat", case=False), "Location"] = "Rabat"
df.loc[df["Location"].str.contains("Canada", case=False), "Location"] = "Canada"
df.loc[df["Location"].str.contains("France", case=False), "Location"] = "France"
df.loc[df["Location"].str.contains("Paris", case=False), "Location"] = "France"
# Enregistrement du dataframe dans un fichier Excel
df.to_excel("result-loc-trait123.xlsx", index=False)

# %%
# Lecture du fichier Excel
df = pd.read_excel(r"C:\Users\ACH\result-loc-trait123.xlsx")

# Traitement de la colonne "Location"
df.loc[df["Location"].str.contains("Casablanca", case=False), "Location"] = "Casablanca "
df.loc[df["Location"].str.contains("Rabat", case=False), "Location"] = "Rabat"
df.loc[df["Location"].str.contains("Canada", case=False), "Location"] = "Canada"
df.loc[df["Location"].str.contains("France", case=False), "Location"] = "France"
df.loc[df["Location"].str.contains("Paris", case=False), "Location"] = "France"
# Enregistrement du dataframe dans un fichier Excel
df.to_excel("result-loc-trait283.xlsx", index=False)

# %%
# Lecture du fichier Excel
df = pd.read_excel(r"C:\Users\ACH\result-loc-trait283.xlsx")

# Traitement de la colonne "Location"
df.loc[df["Company"].str.contains("Orange Business", case=False), "Company"] = "Orange Business"
df.loc[df["Company"].str.contains("Société Générale", case=False), "Company"] = "Société Générale"
df.loc[df["Company"].str.contains("Societe Generale", case=False), "Company"] = "Société Générale"
df.loc[df["Company"].str.contains("OCP", case=False), "Company"] = "OCP"
# Enregistrement du dataframe dans un fichier Excel
df.to_excel("result-loc-traitfinale.xlsx", index=False)
